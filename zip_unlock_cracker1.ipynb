# %%
import zipfile
import time
import sys

# %%
myZip = zipfile.ZipFile('/Users/alexcoleman/Downloads/Beeston.zip')

# %%
myZip
# Out:
# <zipfile.ZipFile filename='/Users/alexcoleman/Downloads/Beeston.zip' mode='r'>

# %%
myZip.extractall(pwd=b'Test')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-39cdbfa59962> in <module>()
# ----> 1 myZip.extractall(pwd=b'Test')
#
# /anaconda3/lib/python3.6/zipfile.py in extractall(self, path, members, pwd)
#    1499
#    1500         for zipinfo in members:
# -> 1501             self._extract_member(zipinfo, path, pwd)
#    1502
#    1503     @classmethod
#
# /anaconda3/lib/python3.6/zipfile.py in _extract_member(self, member, targetpath, pwd)
#    1552             return targetpath
#    1553
# -> 1554         with self.open(member, pwd=pwd) as source, \
#    1555              open(targetpath, "wb") as target:
#    1556             shutil.copyfileobj(source, target)
#
# /anaconda3/lib/python3.6/zipfile.py in open(self, name, mode, pwd, force_zip64)
#    1421                     check_byte = (zinfo.CRC >> 24) & 0xff
#    1422                 if h[11] != check_byte:
# ...

# %%
stringtext = 'test'

# %%
stringtext.encode()
# Out:
# b'test'

# %%
import string
from random import randint

all_str = string.ascii_letters

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
wordlist = ['test1','test3']

# %%
all_str[randint(0,len(all_str))]
# Out:
# 'O'

# %%
for words in range(5):
    
    pswd = []
    
    for x in range(10):
        
        pswd.append(all_str[randint(0,len(all_str))])
    
    print(''.join(pswd))
# Out:
# NKzRteyMTg
# jrmNXAInrr
# KzwknwReRn
# aGGIiQnHxW
# cHqQKVPvTV

# %%
word_lst
# Out:
# ['Z', 'Z', 'Z', 'Z', 'Z']

# %%
for word in wordlist:
        
    for idx in range(len(word)):
        
        new_word = list(word)
        
        for ltr in string.ascii_letters:
            
            new_word[idx] = ltr
            
            print(''.join(new_word))
# Out:
# aest1
# best1
# cest1
# dest1
# eest1
# fest1
# gest1
# hest1
# iest1
# jest1
# kest1
# lest1
# mest1
# nest1
# oest1
# pest1
# qest1
# rest1
# sest1
# test1
# uest1
# vest1
# west1
# xest1
# yest1
# zest1
# Aest1
# Best1
# Cest1
# Dest1
# Eest1
# Fest1
# Gest1
# Hest1
# Iest1
# Jest1
# Kest1
# Lest1
# Mest1
# Nest1
# Oest1
# Pest1
# Qest1
# Rest1
# Sest1
# Test1
# Uest1
# Vest1
# West1
# Xest1
# Yest1
# Zest1
# tast1
# tbst1
# tcst1
# tdst1
# test1
# tfst1
# tgst1
# thst1
# tist1
# tjst1
# tkst1
# tlst1
# tmst1
# tnst1
# tost1
# tpst1
# tqst1
# trst1
# tsst1
# ttst1
# tust1
# tvst1
# twst1
# txst1
# tyst1
# tzst1
# tAst1
# tBst1
# tCst1
# tDst1
# tEst1
# tFst1
# tGst1
# tHst1
# tIst1
# tJst1
# tKst1
# tLst1
# tMst1
# tNst1
# tOst1
# tPst1
# tQst1
# tRst1
# tSst1
# tTst1
# tUst1
# tVst1
# tWst1
# tXst1
# tYst1
# tZst1
# teat1
# tebt1
# tect1
# tedt1
# teet1
# teft1
# tegt1
# teht1
# teit1
# tejt1
# tekt1
# telt1
# temt1
# tent1
# teot1
# tept1
# teqt1
# tert1
# test1
# tett1
# teut1
# ...

# %%
[word for word in wordlist]
# Out:
# ['test1', 'test3']
